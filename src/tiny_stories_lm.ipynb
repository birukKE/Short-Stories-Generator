# %%
import math
import torch
import random
import numpy as np
from torch import nn, optim

from datetime import datetime
from dataclasses import dataclass, asdict
from tokenizer import TinyStoriesTokenizer
from self_attention import MultiHeadSelfAttention

# %% [markdown]
# ## Transformer block
# To obtain a complete transformer block, we add a __position-wise feed-forward layer__ after the self-attention computation. The vectors are first projected to be 4 times wider, a non-linear ``relu'' function is applied, and the vectors are projected down to their original size.
#
# Before and after the self-attention computation, we add a __layer norm__ which normalizes each vector to have mean 0 and variance 1. This contributes to "numerical stability" in the forward pass, i.e. that the numbers within the vectors stay within the bounds representable by a computer.
#
# We also add __residual connections__ to each layer. In general, this means that we compute $x+f(x)$ rather than just $f(x)$ (the "$x+$" is sometimes called the "identity shortcut"). The gradient of $x+f(x)$ is $1+f'(x)$, which is close to 1 if $f'(x)$ is tiny. Without the identity shortcut, the overall gradient in the backward pass could be come extremely small, in particular in a deep network where many layers are stacked. The residual connection thus acts as a prevention for the "vanishing gradient" problem.

# %%
class PositionwiseFFN(nn.Module):
    """
    The position-wise FFN that follows after the self-attention computation.
    Vectors are projected to 4x the dimensionality and then projected down
    again after relu application.
    """

    def __init__(self, vector_dim, dropout_prob) :
        super().__init__()
        self.fc1 = nn.Linear(vector_dim, 4*vector_dim, bias=True)
        self.fc2 = nn.Linear(4*vector_dim, vector_dim, bias=True)
        self.dropout = nn.Dropout(dropout_prob)

    def forward(self, x):
        return self.fc2(self.dropout(torch.relu(self.fc1(x))))

class Block(nn.Module):
    """
    Transformer encoder block.

    This version differs from the original version in  [Vaswani et al. NeurIPS 2017],
    and applies the LayerNorm before the self-attention, and before the FFN, as this
    has proved to be beneficial (see [Nguyen and Salazar 2019]).
    """

    def __init__(self, vector_dim, n_heads, block_size, dropout_prob):
        super().__init__()
        att_dim = vector_dim // n_heads
        self.attn = MultiHeadSelfAttention(vector_dim, n_heads, block_size, is_causal=True)
        self.ffn = PositionwiseFFN(vector_dim, dropout_prob)
        self.dropout = nn.Dropout(dropout_prob)
        self.ln1 = nn.LayerNorm(vector_dim)
        self.ln2 = nn.LayerNorm(vector_dim)

    def forward(self, x):
        x1 = self.ln1(x)
        x2 = x + self.dropout(self.attn(x1))
        x3 = self.ln2(x2)
        x4 = x2 + self.dropout(self.ffn(x3))
        return x4

# %% [markdown]
# ## A generative language model
# Next, we will define a generative language model suitable for the "Tiny Stories" dataset. Our goal is to train it to generate short stories which are similar to the ones in the dataset, without exactly repeating any story in the dataset.
#
# The model will have 4 transformer blocks, each with 4 attention heads. The vector size will be 256, and the context window can contain up to 512 tokens (which is the approximate length of a story in the dataset).
#
# In the forward function, you should __look up the embeddings__ of all the input tokens, __add positional embeddings__, and __apply all the transformer blocks__ in a loop. Finally, you should construct the logits by __applying the final layer__ to the result of the transformer computations. Your task is to implement this function.

# %%
# ============= Hyper-parameters for training ============== #

@dataclass
class Config :
    vocab_size: int = 5000  # This number should agree with the tokenizer
    number_of_transformer_blocks: int = 4
    number_of_attention_heads: int = 4
    vector_dim: int = 256
    block_size: int = 512
    dropout_prob: float = 0.1
    batch_size: int = 8
    learning_rate: float = 0.0005
    weight_decay: float = 0.000001
    no_of_epochs: int = 1
    
config = Config()

class TinyStoriesLM(nn.Module):

    def __init__(self, config):
        super(TinyStoriesLM, self).__init__()
        self.config = config
        self.embed =  nn.Embedding(config.vocab_size, config.vector_dim)
        self.positional = nn.Parameter(torch.randn(1, config.block_size, config.vector_dim))
        modules = [Block(config.vector_dim,\
                         config.number_of_attention_heads,\
                         config.block_size,\
                         config.dropout_prob) for _ in range(config.number_of_transformer_blocks)]
        self.transformers = nn.ModuleList(modules)
        self.final = nn.Linear(config.vector_dim, config.vocab_size)

    def forward(self, x):

        # YOUR CODE HERE

        seq_len = x.shape[1]
        x = self.embed(x)
        x = x + self.positional[:, :seq_len, :]
        for block in self.transformers:
            x = block(x)
        logits = self.final(x)
        
        return logits

    def generate(self, ids, max_new_tokens, temperature=1.0, top_k=None):
        self.eval()
        for _ in range(max_new_tokens):
            ids = ids[-self.config.block_size:]  # Make sure that we don't input more that `block_size` tokens
            logits = self.forward(ids.unsqueeze(0)).squeeze(0)
            logits = logits[-1, :]  # We only want the last time step
            logits = logits / temperature
            if top_k is not None:
                # Only consider the top k classes 
                top_idx = torch.topk(logits, top_k)[1]
                mask = torch.ones(self.config.vocab_size, dtype=torch.bool)
                mask[top_idx] = False
                logits[mask] = float('-inf')
            probs = torch.softmax(logits, dim=-1)
            # Sample from the distribution and append the new token to the input
            next_id = torch.multinomial(probs, num_samples=1)
            ids = torch.cat((ids, next_id), dim=0)
        return ids
        
    @classmethod
    def load(cls, checkpoint_path, device='cpu'):
        """
        Loads a model from a checkpoint file.
        Automatically reconstructs the config and model architecture.
        """
        checkpoint = torch.load(checkpoint_path, map_location=device)
        config = Config(**checkpoint['config'])
        model = cls(config)
        model.load_state_dict(checkpoint['model_state_dict'])
        model.to(device)
    
        print(f"Model loaded from {checkpoint_path} (Epoch {checkpoint['epoch']}, iteration {checkpoint['iteration']})")
        return model

# %% [markdown]
# ### Dataset
# In order to save disk space, we have already tokenized the Tiny Stories dataset for you (this allows every group to share the same file rather than construct theit own, several-GB file). The pretokenized dataset resides in a binary file, and the "TinyStoriesDataset" class below reads from this file.
#
# The "ResumableRandomSampler" class allows us to resume training after a pause, without repeating any previously processed datapoints from the training set.

# %%
from torch.utils.data import Sampler, SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from tokenizer import TinyStoriesTokenizer

class TinyStoriesDataset(Dataset):
    def __init__(self, data_file, block_size):
        """
        data_file: path to the .bin file (uint16 array of token IDs)
        block_size: the context window (e.g., 256 or 512 tokens)
        """

        # Memory-map the data file (RAM usage stays near zero!)
        self.data = np.memmap(data_file, dtype=np.uint16, mode='r')
        self.block_size = block_size

    def __len__(self):
        # We subtract block_size to ensure we don't go out of bounds
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        # Pull a chunk of length block_size + 1 (data and target)
        chunk = self.data[idx : idx + self.block_size + 1]

        # Convert to torch tensors
        x = torch.from_numpy(chunk[:-1].astype(np.int64)) # Input
        y = torch.from_numpy(chunk[1:].astype(np.int64))  # Target (shifted by 1)

        return x, y 


# This class facilitates re-starting training without repeating any past training examples
class ResumableRandomSampler(Sampler):
    def __init__(self, data_source, start_index=0, seed=42):
        self.data_source = data_source
        self.start_index = start_index
        self.seed = seed
        self.generator = torch.Generator()
        self.generator.manual_seed(self.seed)
        
        # 1. Generate the full shuffled list of indices once
        self.indices = torch.randperm(len(self.data_source), generator=self.generator).tolist()

    def __iter__(self):
        # 2. Slice the indices to only include those from start_index onwards
        return iter(self.indices[self.start_index:])

    def __len__(self):
        return len(self.indices) - self.start_index

# %% [markdown]
# ### One sequence yields many training examples
# A common misconception is that one "sequence" (a chunk of text) equals one "training example." But, as illustrated by the example in the next cell, the sequence contains as many training examples as tokens.
#
# When we provide the model with a sequence of length $T$ (our ``block_size``), the model generates $T$ separate sets of logits (predictions). Because the causal mask prevents the model from "looking ahead," each position $t$ must predict the token at $t+1$ using only the information from indices $0\ldots t$.

# %%
# Let's have a look at some data
training_dataset = TinyStoriesDataset('/datasets/dd2417/train.bin', config.block_size)
tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')
sample_idx = 42  
x_sample, y_sample = training_dataset[sample_idx]

# We'll just look at the first 10 tokens for clarity
tokens_x = x_sample[:10].tolist()
tokens_y = y_sample[:10].tolist()
print(tokens_x)
print(tokens_y)
print()

print(f"{'Context (Input x)':<40} | {'Target (Label y)':<15}")
print("-" * 60)

for i in range(1, len(tokens_x) + 1):
    # The context grows as we move through the sequence
    context_ids = tokens_x[:i]
    context_text = "".join(tokenizer.vocab[id] for id in context_ids)
    
    # The target is always the 'next' token in the sequence
    target_id = tokens_y[i-1]
    target_text = tokenizer.vocab[target_id]
    
    print(f"{context_text:>40} ---> {target_text:<15}")
# Out:
# [70, 212, 135, 158, 114, 1401, 70, 96, 195, 1204]
# [212, 135, 158, 114, 1401, 70, 96, 195, 1204, 81]
#
# Context (Input x)                        | Target (Label y)
# ------------------------------------------------------------
#                                        , --->  but
#                                    , but --->  in
#                                 , but in --->  his
#                             , but in his --->  ha
#                          , but in his ha ---> ste
#                       , but in his haste ---> ,
#                      , but in his haste, --->  he
#                   , but in his haste, he --->  had
#               , but in his haste, he had --->  forgot
#        , but in his haste, he had forgot --->  to

# %% [markdown]
# If we have a batch size of 8 and a sequence length of 512, the model will return a (8, 512, 5000) tensor of logits (where 5000 is the number of token classes), and we have a (8, 512) tensor of targets. During training, we now reshape these into a (8 $\times$ 512, 5000) tensor of logits and an (8 $\times$ 512) tensor of targets, respectively. The ``nn.CrossEntropyLoss`` class will compute all the 8 $\times$ 512 = 4096 individual losses and average them in a single forward pass. With a GPU, this can be done very efficiently.
#
# It is this tremendous efficiency that has popularized the Transformer architecture. With older architectures like the Recurrent Neural Network (RNN), the model would have to make 4096 forward passes to achieve the same progress.
#
# In each iteration of the training loop below, we input a sequence of text containing ``block_size`` tokens. It might happen the one story ends and another story starts in the middle of such a sequence, but we don't care too much about this. Validation loss is computed on a separate "dev" set after every 100 training sequences.  The dev set is small (about 1% of the training set). A model checkpoint is saved every 10,000 training sequences. The checkpoint can be used for further training, or for inference (i.e., using the model).

# %%
import os

# ======================= Training ======================= #

# Remove the checkpoint file if you want to train from scratch
checkpoint_path = 'last_checkpoint.pt'
RESUME_TRAINING = os.path.exists(checkpoint_path) 

seed = 42
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print( "Running on", device )

tokenizer = TinyStoriesTokenizer.load('/datasets/dd2417/tokenizer.json')

if RESUME_TRAINING:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    print(f"Model loaded from {checkpoint_path} (Epoch {checkpoint['epoch']+1}, iteration {checkpoint['iteration']})")
    config = Config(**checkpoint['config'])
    lm = TinyStoriesLM(config)
    # Sanity check
    if tokenizer.vocab_size != lm.config.vocab_size:
        print("WARNING: The tokenizer's and the model's vocab_size are different!")
    lm.load_state_dict(checkpoint['model_state_dict'])
    lm.to(device) 
else :
    config = Config()
    config.vocab_size = tokenizer.vocab_size
    lm = TinyStoriesLM(config).to(device)

lm_optimizer = torch.optim.AdamW(lm.parameters(), lr=lm.config.learning_rate, weight_decay=config.weight_decay)

if RESUME_TRAINING:
    lm_optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

training_dataset = TinyStoriesDataset('/datasets/dd2417/train.bin', config.block_size)

# Development set 
dev_dataset = TinyStoriesDataset('/datasets/dd2417/dev.bin', config.block_size)
# Create indices that jump by the block size. This ensures we only see each 
# chunk of text once when computing validation loss.
dev_indices = list(range(0, len(dev_dataset), config.block_size))
dev_subset = torch.utils.data.Subset(dev_dataset, dev_indices)
dev_loader = DataLoader(dev_subset, config.batch_size, pin_memory=True)

print( "There are", len(training_dataset), "datapoints and", tokenizer.vocab_size, "token classes in the dataset" ) 

criterion = nn.CrossEntropyLoss()

lm.train()
running_loss = 0
print( datetime.now().strftime("%X"), "Training starts" )
# Can we pick up where we left off?
start_epoch = checkpoint['epoch'] if RESUME_TRAINING else 0
start_iter = checkpoint['iteration'] if RESUME_TRAINING else 0
for epoch in range(start_epoch, config.no_of_epochs) :
    iteration = start_iter if epoch == start_epoch else 0
    # Random sampling of datapoints. Note that we use a new seed for each epoch 
    # -- this will guarantee that we can resume the training anywhere without 
    # repeating any datapoints within an epoch.
    sampler = ResumableRandomSampler(training_dataset, 
                                     start_index=iteration * config.batch_size, 
                                     seed=seed+epoch) 
    training_loader = DataLoader(training_dataset, 
                                 batch_size=config.batch_size, 
                                 sampler=sampler, 
                                 num_workers=4)
    for x,y in training_loader:
        x,y = x.to(device), y.to(device)
        lm_optimizer.zero_grad()
        logits = lm(x)
        loss = criterion(logits.reshape(-1, tokenizer.vocab_size), y.reshape(-1))
        loss.backward()
        lm_optimizer.step()
        running_loss += loss.detach().item()
        iteration += 1
        if iteration%100 == 0:
            # Compute validation loss every 100 iterations
            lm.eval()   
            with torch.no_grad():
                total_loss = 0    
                for vx, vy in dev_loader:
                    vx,vy = vx.to(device), vy.to(device)
                    logits = lm(vx)
                    val_loss = criterion(logits.reshape(-1, tokenizer.vocab_size), vy.reshape(-1))
                    total_loss += val_loss.item()
                print(f'{datetime.now().strftime("%X")} Epoch {epoch+1}, iteration {iteration}: loss={running_loss/100:.4f}, dev loss={total_loss/len(dev_loader):.4f}')
            lm.train()
            running_loss = 0
        if iteration%10000 == 0:
            checkpoint = {
                'model_state_dict': lm.state_dict(),
                'optimizer_state_dict': lm_optimizer.state_dict(),
                'epoch': epoch,
                'iteration': iteration,
                'config': config.__dict__, # Useful so you know the architecture later
            }

            # Overwrites the same file every time to save space
            torch.save(checkpoint, checkpoint_path)
            print(f"Checkpoint saved to {checkpoint_path}")

            # Show progress by generating a story
            lm.eval()
            prompt = "Once upon a time"
            _, start_ids = tokenizer.tokenize(prompt)
            x = torch.tensor(start_ids, dtype=torch.long, device=device)
            with torch.no_grad():
                y = lm.generate(x, max_new_tokens=100, temperature=0.8, top_k=40)
            decoded_output = [tokenizer.vocab[i] for i in y.tolist()]
            print("-" * 30)
            print("".join(decoded_output))
            print("-" * 30)
            lm.train()
# Out:
# Running on cuda
# Model loaded from last_checkpoint.pt (Epoch 1, iteration 990000)
# There are 18507842 datapoints and 5000 token classes in the dataset
# 19:56:06 Training starts
# 19:56:11 Epoch 1, iteration 990100: loss=1.4046, dev loss=1.5377
# 19:56:14 Epoch 1, iteration 990200: loss=1.4027, dev loss=1.5387
# 19:56:18 Epoch 1, iteration 990300: loss=1.3870, dev loss=1.5382
# 19:56:21 Epoch 1, iteration 990400: loss=1.3957, dev loss=1.5396
# 19:56:25 Epoch 1, iteration 990500: loss=1.4033, dev loss=1.5359
# 19:56:28 Epoch 1, iteration 990600: loss=1.3935, dev loss=1.5380
# 19:56:32 Epoch 1, iteration 990700: loss=1.4037, dev loss=1.5380
# 19:56:35 Epoch 1, iteration 990800: loss=1.3994, dev loss=1.5393
# 19:56:39 Epoch 1, iteration 990900: loss=1.3911, dev loss=1.5384
# 19:56:42 Epoch 1, iteration 991000: loss=1.4092, dev loss=1.5376
# 19:56:46 Epoch 1, iteration 991100: loss=1.3947, dev loss=1.5403
# 19:56:49 Epoch 1, iteration 991200: loss=1.4015, dev loss=1.5390
# 19:56:53 Epoch 1, iteration 991300: loss=1.3868, dev loss=1.5395
# 19:56:56 Epoch 1, iteration 991400: loss=1.3966, dev loss=1.5378
# 19:57:00 Epoch 1, iteration 991500: loss=1.3936, dev loss=1.5390
# 19:57:03 Epoch 1, iteration 991600: loss=1.4008, dev loss=1.5407
# 19:57:07 Epoch 1, iteration 991700: loss=1.3894, dev loss=1.5396
# 19:57:10 Epoch 1, iteration 991800: loss=1.3893, dev loss=1.5381
# 19:57:14 Epoch 1, iteration 991900: loss=1.3880, dev loss=1.5404
# 19:57:17 Epoch 1, iteration 992000: loss=1.3915, dev loss=1.5382
# 19:57:21 Epoch 1, iteration 992100: loss=1.3919, dev loss=1.5379
# 19:57:24 Epoch 1, iteration 992200: loss=1.3963, dev loss=1.5419
# 19:57:27 Epoch 1, iteration 992300: loss=1.3940, dev loss=1.5387
# 19:57:31 Epoch 1, iteration 992400: loss=1.3966, dev loss=1.5382
# 19:57:34 Epoch 1, iteration 992500: loss=1.4024, dev loss=1.5363
# 19:57:38 Epoch 1, iteration 992600: loss=1.3923, dev loss=1.5367
# 19:57:41 Epoch 1, iteration 992700: loss=1.3918, dev loss=1.5396
# 19:57:45 Epoch 1, iteration 992800: loss=1.4111, dev loss=1.5372
# 19:57:48 Epoch 1, iteration 992900: loss=1.3884, dev loss=1.5402
# 19:57:52 Epoch 1, iteration 993000: loss=1.4040, dev loss=1.5378
# 19:57:55 Epoch 1, iteration 993100: loss=1.4032, dev loss=1.5380
# 19:57:59 Epoch 1, iteration 993200: loss=1.4023, dev loss=1.5389
# 19:58:02 Epoch 1, iteration 993300: loss=1.3843, dev loss=1.5368
# 19:58:06 Epoch 1, iteration 993400: loss=1.4072, dev loss=1.5379
# 19:58:09 Epoch 1, iteration 993500: loss=1.4046, dev loss=1.5381
# 19:58:13 Epoch 1, iteration 993600: loss=1.4086, dev loss=1.5386
# 19:58:16 Epoch 1, iteration 993700: loss=1.4049, dev loss=1.5387
# 19:58:19 Epoch 1, iteration 993800: loss=1.3885, dev loss=1.5383
# 19:58:23 Epoch 1, iteration 993900: loss=1.4014, dev loss=1.5381
# 19:58:26 Epoch 1, iteration 994000: loss=1.3925, dev loss=1.5386
# 19:58:30 Epoch 1, iteration 994100: loss=1.3888, dev loss=1.5388
# 19:58:33 Epoch 1, iteration 994200: loss=1.3900, dev loss=1.5392
# 19:58:37 Epoch 1, iteration 994300: loss=1.3971, dev loss=1.5379
# 19:58:40 Epoch 1, iteration 994400: loss=1.4035, dev loss=1.5378
# 19:58:44 Epoch 1, iteration 994500: loss=1.3843, dev loss=1.5401
# 19:58:47 Epoch 1, iteration 994600: loss=1.3834, dev loss=1.5411
# 19:58:51 Epoch 1, iteration 994700: loss=1.3958, dev loss=1.5379
# 19:58:54 Epoch 1, iteration 994800: loss=1.3910, dev loss=1.5391
# 19:58:58 Epoch 1, iteration 994900: loss=1.4010, dev loss=1.5402
# 19:59:01 Epoch 1, iteration 995000: loss=1.3985, dev loss=1.5397
# 19:59:05 Epoch 1, iteration 995100: loss=1.4017, dev loss=1.5401
# 19:59:08 Epoch 1, iteration 995200: loss=1.3902, dev loss=1.5382
# 19:59:11 Epoch 1, iteration 995300: loss=1.4006, dev loss=1.5376
# 19:59:15 Epoch 1, iteration 995400: loss=1.3990, dev loss=1.5377
# 19:59:18 Epoch 1, iteration 995500: loss=1.3928, dev loss=1.5379
# 19:59:22 Epoch 1, iteration 995600: loss=1.3985, dev loss=1.5366
# 19:59:25 Epoch 1, iteration 995700: loss=1.3917, dev loss=1.5367
# 19:59:29 Epoch 1, iteration 995800: loss=1.4065, dev loss=1.5371
# 19:59:32 Epoch 1, iteration 995900: loss=1.3931, dev loss=1.5361
# 19:59:36 Epoch 1, iteration 996000: loss=1.3991, dev loss=1.5394
# 19:59:39 Epoch 1, iteration 996100: loss=1.3881, dev loss=1.5383
# 19:59:43 Epoch 1, iteration 996200: loss=1.4062, dev loss=1.5364
# 19:59:46 Epoch 1, iteration 996300: loss=1.3910, dev loss=1.5396
# 19:59:50 Epoch 1, iteration 996400: loss=1.3913, dev loss=1.5388
# 19:59:53 Epoch 1, iteration 996500: loss=1.4029, dev loss=1.5375
# 19:59:57 Epoch 1, iteration 996600: loss=1.4056, dev loss=1.5399
# 20:00:00 Epoch 1, iteration 996700: loss=1.4101, dev loss=1.5399
# 20:00:03 Epoch 1, iteration 996800: loss=1.4079, dev loss=1.5364
# 20:00:07 Epoch 1, iteration 996900: loss=1.4013, dev loss=1.5399
# 20:00:10 Epoch 1, iteration 997000: loss=1.3862, dev loss=1.5368
# 20:00:14 Epoch 1, iteration 997100: loss=1.4043, dev loss=1.5373
# 20:00:17 Epoch 1, iteration 997200: loss=1.4078, dev loss=1.5387
# 20:00:21 Epoch 1, iteration 997300: loss=1.3949, dev loss=1.5387
# 20:00:24 Epoch 1, iteration 997400: loss=1.4055, dev loss=1.5378
# 20:00:28 Epoch 1, iteration 997500: loss=1.4065, dev loss=1.5369
# 20:00:31 Epoch 1, iteration 997600: loss=1.4000, dev loss=1.5390
# 20:00:35 Epoch 1, iteration 997700: loss=1.3960, dev loss=1.5377
# 20:00:38 Epoch 1, iteration 997800: loss=1.3936, dev loss=1.5399
# 20:00:42 Epoch 1, iteration 997900: loss=1.4105, dev loss=1.5364
# 20:00:45 Epoch 1, iteration 998000: loss=1.3925, dev loss=1.5400
# 20:00:49 Epoch 1, iteration 998100: loss=1.3885, dev loss=1.5374
# 20:00:52 Epoch 1, iteration 998200: loss=1.3959, dev loss=1.5376
# 20:00:56 Epoch 1, iteration 998300: loss=1.4031, dev loss=1.5382
# 20:00:59 Epoch 1, iteration 998400: loss=1.4022, dev loss=1.5365
# 20:01:02 Epoch 1, iteration 998500: loss=1.4039, dev loss=1.5376
# 20:01:06 Epoch 1, iteration 998600: loss=1.3953, dev loss=1.5372
# 20:01:09 Epoch 1, iteration 998700: loss=1.3967, dev loss=1.5367
# 20:01:13 Epoch 1, iteration 998800: loss=1.3999, dev loss=1.5362
# 20:01:16 Epoch 1, iteration 998900: loss=1.3971, dev loss=1.5363
# 20:01:20 Epoch 1, iteration 999000: loss=1.3912, dev loss=1.5362
# 20:01:23 Epoch 1, iteration 999100: loss=1.3883, dev loss=1.5387
# 20:01:27 Epoch 1, iteration 999200: loss=1.4052, dev loss=1.5344
# 20:01:30 Epoch 1, iteration 999300: loss=1.4027, dev loss=1.5371
# 20:01:34 Epoch 1, iteration 999400: loss=1.3989, dev loss=1.5401
# 20:01:37 Epoch 1, iteration 999500: loss=1.4084, dev loss=1.5360
# 20:01:41 Epoch 1, iteration 999600: loss=1.4078, dev loss=1.5393
# 20:01:44 Epoch 1, iteration 999700: loss=1.3885, dev loss=1.5378
# 20:01:47 Epoch 1, iteration 999800: loss=1.3954, dev loss=1.5360
# 20:01:51 Epoch 1, iteration 999900: loss=1.3935, dev loss=1.5392
# 20:01:54 Epoch 1, iteration 1000000: loss=1.4087, dev loss=1.5345
# Checkpoint saved to last_checkpoint.pt
# ------------------------------
# Once upon a time there was a big bird. He was very intelligent. Every day he would peck as small as he could. One day he noticed something strange. He saw a tiny hole in the ground. He peered inside and found a beautiful pearl. He was so excited he started to touch it. But the sharp sound was too loud. Then the pearl started to sing a beautiful song. The angry bird was so surprised! He looked around but he couldn't hear anything. He felt very sad and
# ------------------------------
# 20:01:58 Epoch 1, iteration 1000100: loss=1.3984, dev loss=1.5359
# 20:02:02 Epoch 1, iteration 1000200: loss=1.3940, dev loss=1.5360
# 20:02:05 Epoch 1, iteration 1000300: loss=1.3936, dev loss=1.5358
# 20:02:09 Epoch 1, iteration 1000400: loss=1.3885, dev loss=1.5379
# 20:02:12 Epoch 1, iteration 1000500: loss=1.4058, dev loss=1.5371
# 20:02:16 Epoch 1, iteration 1000600: loss=1.4012, dev loss=1.5356
# 20:02:19 Epoch 1, iteration 1000700: loss=1.3948, dev loss=1.5394
# 20:02:23 Epoch 1, iteration 1000800: loss=1.4017, dev loss=1.5384
# 20:02:26 Epoch 1, iteration 1000900: loss=1.4056, dev loss=1.5379
# 20:02:30 Epoch 1, iteration 1001000: loss=1.3998, dev loss=1.5363
# 20:02:33 Epoch 1, iteration 1001100: loss=1.3908, dev loss=1.5355
# 20:02:37 Epoch 1, iteration 1001200: loss=1.3871, dev loss=1.5374
# 20:02:40 Epoch 1, iteration 1001300: loss=1.3965, dev loss=1.5356
# 20:02:44 Epoch 1, iteration 1001400: loss=1.3779, dev loss=1.5359
# 20:02:47 Epoch 1, iteration 1001500: loss=1.3943, dev loss=1.5361
# 20:02:51 Epoch 1, iteration 1001600: loss=1.4024, dev loss=1.5365
# 20:02:54 Epoch 1, iteration 1001700: loss=1.4033, dev loss=1.5357
# 20:02:58 Epoch 1, iteration 1001800: loss=1.4023, dev loss=1.5356
# 20:03:01 Epoch 1, iteration 1001900: loss=1.3981, dev loss=1.5348
# 20:03:05 Epoch 1, iteration 1002000: loss=1.3969, dev loss=1.5356
# 20:03:08 Epoch 1, iteration 1002100: loss=1.3969, dev loss=1.5368
# 20:03:11 Epoch 1, iteration 1002200: loss=1.4004, dev loss=1.5369
# 20:03:15 Epoch 1, iteration 1002300: loss=1.3952, dev loss=1.5378
# 20:03:18 Epoch 1, iteration 1002400: loss=1.4066, dev loss=1.5374
# 20:03:22 Epoch 1, iteration 1002500: loss=1.3871, dev loss=1.5374
# 20:03:25 Epoch 1, iteration 1002600: loss=1.3953, dev loss=1.5352
# 20:03:29 Epoch 1, iteration 1002700: loss=1.3944, dev loss=1.5361
# 20:03:32 Epoch 1, iteration 1002800: loss=1.3955, dev loss=1.5365
# 20:03:36 Epoch 1, iteration 1002900: loss=1.3915, dev loss=1.5370
# 20:03:39 Epoch 1, iteration 1003000: loss=1.3939, dev loss=1.5374
# 20:03:43 Epoch 1, iteration 1003100: loss=1.4060, dev loss=1.5361
# 20:03:46 Epoch 1, iteration 1003200: loss=1.4053, dev loss=1.5369
# 20:03:50 Epoch 1, iteration 1003300: loss=1.4127, dev loss=1.5385
# 20:03:53 Epoch 1, iteration 1003400: loss=1.4066, dev loss=1.5370
# 20:03:57 Epoch 1, iteration 1003500: loss=1.3975, dev loss=1.5363
# 20:04:00 Epoch 1, iteration 1003600: loss=1.3902, dev loss=1.5395
# 20:04:04 Epoch 1, iteration 1003700: loss=1.3981, dev loss=1.5351
# 20:04:07 Epoch 1, iteration 1003800: loss=1.4155, dev loss=1.5375
# 20:04:11 Epoch 1, iteration 1003900: loss=1.3851, dev loss=1.5371
# 20:04:14 Epoch 1, iteration 1004000: loss=1.3964, dev loss=1.5393
# 20:04:18 Epoch 1, iteration 1004100: loss=1.3996, dev loss=1.5371
# 20:04:21 Epoch 1, iteration 1004200: loss=1.3843, dev loss=1.5380
# 20:04:25 Epoch 1, iteration 1004300: loss=1.3974, dev loss=1.5375
# 20:04:28 Epoch 1, iteration 1004400: loss=1.4030, dev loss=1.5367
# 20:04:32 Epoch 1, iteration 1004500: loss=1.4080, dev loss=1.5385
# 20:04:35 Epoch 1, iteration 1004600: loss=1.3951, dev loss=1.5375
# 20:04:38 Epoch 1, iteration 1004700: loss=1.4046, dev loss=1.5372
# 20:04:42 Epoch 1, iteration 1004800: loss=1.3912, dev loss=1.5355
# 20:04:45 Epoch 1, iteration 1004900: loss=1.4135, dev loss=1.5372
# 20:04:49 Epoch 1, iteration 1005000: loss=1.3932, dev loss=1.5365
# 20:04:52 Epoch 1, iteration 1005100: loss=1.3926, dev loss=1.5361
# 20:04:56 Epoch 1, iteration 1005200: loss=1.3859, dev loss=1.5364
# 20:04:59 Epoch 1, iteration 1005300: loss=1.3921, dev loss=1.5374
# 20:05:03 Epoch 1, iteration 1005400: loss=1.3943, dev loss=1.5386
# 20:05:06 Epoch 1, iteration 1005500: loss=1.3937, dev loss=1.5400
# 20:05:10 Epoch 1, iteration 1005600: loss=1.3957, dev loss=1.5368
# 20:05:13 Epoch 1, iteration 1005700: loss=1.4035, dev loss=1.5376
# 20:05:17 Epoch 1, iteration 1005800: loss=1.4027, dev loss=1.5369
# 20:05:20 Epoch 1, iteration 1005900: loss=1.4050, dev loss=1.5355
# 20:05:24 Epoch 1, iteration 1006000: loss=1.3989, dev loss=1.5372
# 20:05:27 Epoch 1, iteration 1006100: loss=1.3919, dev loss=1.5366
# 20:05:31 Epoch 1, iteration 1006200: loss=1.3835, dev loss=1.5375
# 20:05:34 Epoch 1, iteration 1006300: loss=1.3974, dev loss=1.5381
# 20:05:38 Epoch 1, iteration 1006400: loss=1.3983, dev loss=1.5371
# 20:05:41 Epoch 1, iteration 1006500: loss=1.4045, dev loss=1.5360
# 20:05:45 Epoch 1, iteration 1006600: loss=1.3960, dev loss=1.5392
# 20:05:48 Epoch 1, iteration 1006700: loss=1.3907, dev loss=1.5375
# 20:05:52 Epoch 1, iteration 1006800: loss=1.4014, dev loss=1.5386
# 20:05:55 Epoch 1, iteration 1006900: loss=1.3961, dev loss=1.5381
# 20:05:59 Epoch 1, iteration 1007000: loss=1.3887, dev loss=1.5394
# 20:06:02 Epoch 1, iteration 1007100: loss=1.3981, dev loss=1.5369
# 20:06:06 Epoch 1, iteration 1007200: loss=1.3948, dev loss=1.5369
# 20:06:09 Epoch 1, iteration 1007300: loss=1.3984, dev loss=1.5389
# 20:06:13 Epoch 1, iteration 1007400: loss=1.3945, dev loss=1.5381
# 20:06:16 Epoch 1, iteration 1007500: loss=1.4038, dev loss=1.5383
# 20:06:19 Epoch 1, iteration 1007600: loss=1.3905, dev loss=1.5397
# 20:06:23 Epoch 1, iteration 1007700: loss=1.3934, dev loss=1.5385
# 20:06:27 Epoch 1, iteration 1007800: loss=1.3969, dev loss=1.5396
# 20:06:30 Epoch 1, iteration 1007900: loss=1.3989, dev loss=1.5366
# 20:06:34 Epoch 1, iteration 1008000: loss=1.3919, dev loss=1.5370
# 20:06:37 Epoch 1, iteration 1008100: loss=1.3899, dev loss=1.5365
# 20:06:41 Epoch 1, iteration 1008200: loss=1.3971, dev loss=1.5401
# 20:06:44 Epoch 1, iteration 1008300: loss=1.4006, dev loss=1.5370
# 20:06:48 Epoch 1, iteration 1008400: loss=1.3984, dev loss=1.5390
# 20:06:51 Epoch 1, iteration 1008500: loss=1.3990, dev loss=1.5393
# 20:06:55 Epoch 1, iteration 1008600: loss=1.3968, dev loss=1.5359
# 20:06:58 Epoch 1, iteration 1008700: loss=1.4036, dev loss=1.5369
# 20:07:02 Epoch 1, iteration 1008800: loss=1.3918, dev loss=1.5367
# 20:07:05 Epoch 1, iteration 1008900: loss=1.3995, dev loss=1.5379
# 20:07:09 Epoch 1, iteration 1009000: loss=1.4001, dev loss=1.5364
# 20:07:12 Epoch 1, iteration 1009100: loss=1.3973, dev loss=1.5362
# 20:07:16 Epoch 1, iteration 1009200: loss=1.4099, dev loss=1.5369
# 20:07:19 Epoch 1, iteration 1009300: loss=1.3986, dev loss=1.5386
# 20:07:23 Epoch 1, iteration 1009400: loss=1.3977, dev loss=1.5371
# 20:07:26 Epoch 1, iteration 1009500: loss=1.4022, dev loss=1.5355
# 20:07:30 Epoch 1, iteration 1009600: loss=1.3954, dev loss=1.5371
# 20:07:33 Epoch 1, iteration 1009700: loss=1.4011, dev loss=1.5377
# 20:07:37 Epoch 1, iteration 1009800: loss=1.3979, dev loss=1.5361
# 20:07:40 Epoch 1, iteration 1009900: loss=1.3990, dev loss=1.5356
# 20:07:44 Epoch 1, iteration 1010000: loss=1.3984, dev loss=1.5363
# Checkpoint saved to last_checkpoint.pt
# ------------------------------
# Once upon a time, there was a little girl named Lily. She loved to play outside in the grass. One day, her mom told her to be careful and not to be careless. Later that day, Lily and her mom went to a restaurant to eat. The waiter gave her some yummy food and ordered room for dessert. Lily was so excited to eat it, but she remembered her mom always told her to be careful when cooking. When the food arrived, Lily ate it all up. But then, she
# ------------------------------
# 20:07:48 Epoch 1, iteration 1010100: loss=1.3934, dev loss=1.5361
# 20:07:51 Epoch 1, iteration 1010200: loss=1.3943, dev loss=1.5377
# 20:07:55 Epoch 1, iteration 1010300: loss=1.4064, dev loss=1.5385
# 20:07:58 Epoch 1, iteration 1010400: loss=1.3949, dev loss=1.5370
# 20:08:02 Epoch 1, iteration 1010500: loss=1.3929, dev loss=1.5375
# 20:08:05 Epoch 1, iteration 1010600: loss=1.3964, dev loss=1.5416
# 20:08:09 Epoch 1, iteration 1010700: loss=1.3866, dev loss=1.5395
# 20:08:12 Epoch 1, iteration 1010800: loss=1.3825, dev loss=1.5386
# 20:08:16 Epoch 1, iteration 1010900: loss=1.3973, dev loss=1.5371
# 20:08:19 Epoch 1, iteration 1011000: loss=1.3877, dev loss=1.5382
# 20:08:23 Epoch 1, iteration 1011100: loss=1.3927, dev loss=1.5389
# 20:08:26 Epoch 1, iteration 1011200: loss=1.3822, dev loss=1.5393
# 20:08:30 Epoch 1, iteration 1011300: loss=1.3926, dev loss=1.5399
# 20:08:33 Epoch 1, iteration 1011400: loss=1.3928, dev loss=1.5386
# 20:08:37 Epoch 1, iteration 1011500: loss=1.4016, dev loss=1.5372
# 20:08:40 Epoch 1, iteration 1011600: loss=1.3970, dev loss=1.5382
# 20:08:44 Epoch 1, iteration 1011700: loss=1.3999, dev loss=1.5382
# 20:08:47 Epoch 1, iteration 1011800: loss=1.3844, dev loss=1.5395
# 20:08:51 Epoch 1, iteration 1011900: loss=1.4066, dev loss=1.5377
# 20:08:54 Epoch 1, iteration 1012000: loss=1.3934, dev loss=1.5372
# 20:08:58 Epoch 1, iteration 1012100: loss=1.4027, dev loss=1.5368
# 20:09:01 Epoch 1, iteration 1012200: loss=1.4031, dev loss=1.5394
# 20:09:05 Epoch 1, iteration 1012300: loss=1.3997, dev loss=1.5385
# 20:09:08 Epoch 1, iteration 1012400: loss=1.3981, dev loss=1.5378
# 20:09:12 Epoch 1, iteration 1012500: loss=1.3941, dev loss=1.5391
# 20:09:16 Epoch 1, iteration 1012600: loss=1.3979, dev loss=1.5369
# 20:09:19 Epoch 1, iteration 1012700: loss=1.3987, dev loss=1.5380
# 20:09:23 Epoch 1, iteration 1012800: loss=1.4022, dev loss=1.5387
# 20:09:26 Epoch 1, iteration 1012900: loss=1.3938, dev loss=1.5365
# 20:09:30 Epoch 1, iteration 1013000: loss=1.3996, dev loss=1.5365
# 20:09:33 Epoch 1, iteration 1013100: loss=1.3934, dev loss=1.5369
# 20:09:37 Epoch 1, iteration 1013200: loss=1.3962, dev loss=1.5370
# 20:09:40 Epoch 1, iteration 1013300: loss=1.4082, dev loss=1.5374
# 20:09:44 Epoch 1, iteration 1013400: loss=1.3923, dev loss=1.5394
# 20:09:47 Epoch 1, iteration 1013500: loss=1.4022, dev loss=1.5357
# 20:09:51 Epoch 1, iteration 1013600: loss=1.3951, dev loss=1.5380
# 20:09:54 Epoch 1, iteration 1013700: loss=1.4026, dev loss=1.5370
# 20:09:58 Epoch 1, iteration 1013800: loss=1.4048, dev loss=1.5375
# 20:10:01 Epoch 1, iteration 1013900: loss=1.3891, dev loss=1.5383
# 20:10:05 Epoch 1, iteration 1014000: loss=1.4114, dev loss=1.5374
# 20:10:08 Epoch 1, iteration 1014100: loss=1.4056, dev loss=1.5372
# 20:10:12 Epoch 1, iteration 1014200: loss=1.3942, dev loss=1.5359
# 20:10:15 Epoch 1, iteration 1014300: loss=1.3948, dev loss=1.5385
# 20:10:19 Epoch 1, iteration 1014400: loss=1.3931, dev loss=1.5377
# 20:10:22 Epoch 1, iteration 1014500: loss=1.4013, dev loss=1.5361
# 20:10:26 Epoch 1, iteration 1014600: loss=1.4033, dev loss=1.5369
# 20:10:29 Epoch 1, iteration 1014700: loss=1.3952, dev loss=1.5377
# 20:10:33 Epoch 1, iteration 1014800: loss=1.3984, dev loss=1.5365
# 20:10:36 Epoch 1, iteration 1014900: loss=1.3962, dev loss=1.5372
# 20:10:40 Epoch 1, iteration 1015000: loss=1.4018, dev loss=1.5371
# 20:10:43 Epoch 1, iteration 1015100: loss=1.4044, dev loss=1.5357
# 20:10:47 Epoch 1, iteration 1015200: loss=1.3995, dev loss=1.5359
# 20:10:50 Epoch 1, iteration 1015300: loss=1.3918, dev loss=1.5355
# 20:10:54 Epoch 1, iteration 1015400: loss=1.4056, dev loss=1.5353
# 20:10:57 Epoch 1, iteration 1015500: loss=1.3915, dev loss=1.5349
# 20:11:01 Epoch 1, iteration 1015600: loss=1.3814, dev loss=1.5358
# 20:11:04 Epoch 1, iteration 1015700: loss=1.3997, dev loss=1.5363
# 20:11:08 Epoch 1, iteration 1015800: loss=1.3862, dev loss=1.5364
# 20:11:11 Epoch 1, iteration 1015900: loss=1.3917, dev loss=1.5360
# 20:11:15 Epoch 1, iteration 1016000: loss=1.3969, dev loss=1.5362
# 20:11:18 Epoch 1, iteration 1016100: loss=1.4069, dev loss=1.5386
# 20:11:22 Epoch 1, iteration 1016200: loss=1.3881, dev loss=1.5394
# 20:11:25 Epoch 1, iteration 1016300: loss=1.3941, dev loss=1.5387
# 20:11:29 Epoch 1, iteration 1016400: loss=1.3964, dev loss=1.5373
# 20:11:32 Epoch 1, iteration 1016500: loss=1.3896, dev loss=1.5392
# 20:11:36 Epoch 1, iteration 1016600: loss=1.3940, dev loss=1.5379
# 20:11:39 Epoch 1, iteration 1016700: loss=1.3836, dev loss=1.5374
# 20:11:43 Epoch 1, iteration 1016800: loss=1.3903, dev loss=1.5373
# 20:11:46 Epoch 1, iteration 1016900: loss=1.3989, dev loss=1.5379
# 20:11:50 Epoch 1, iteration 1017000: loss=1.3942, dev loss=1.5355
# 20:11:53 Epoch 1, iteration 1017100: loss=1.4075, dev loss=1.5371
# 20:11:57 Epoch 1, iteration 1017200: loss=1.3964, dev loss=1.5375
# 20:12:00 Epoch 1, iteration 1017300: loss=1.3949, dev loss=1.5377
# 20:12:04 Epoch 1, iteration 1017400: loss=1.3903, dev loss=1.5376
# 20:12:07 Epoch 1, iteration 1017500: loss=1.4090, dev loss=1.5365
# 20:12:11 Epoch 1, iteration 1017600: loss=1.4004, dev loss=1.5379
# 20:12:14 Epoch 1, iteration 1017700: loss=1.4101, dev loss=1.5376
# 20:12:18 Epoch 1, iteration 1017800: loss=1.3965, dev loss=1.5368
# 20:12:21 Epoch 1, iteration 1017900: loss=1.3975, dev loss=1.5386
# 20:12:25 Epoch 1, iteration 1018000: loss=1.4019, dev loss=1.5381
# 20:12:28 Epoch 1, iteration 1018100: loss=1.3936, dev loss=1.5378
# 20:12:32 Epoch 1, iteration 1018200: loss=1.3977, dev loss=1.5391
# 20:12:35 Epoch 1, iteration 1018300: loss=1.3894, dev loss=1.5360
# 20:12:39 Epoch 1, iteration 1018400: loss=1.3961, dev loss=1.5377
# 20:12:42 Epoch 1, iteration 1018500: loss=1.3848, dev loss=1.5368
# 20:12:46 Epoch 1, iteration 1018600: loss=1.3907, dev loss=1.5369
# 20:12:49 Epoch 1, iteration 1018700: loss=1.3934, dev loss=1.5360
# 20:12:52 Epoch 1, iteration 1018800: loss=1.4004, dev loss=1.5351
# 20:12:56 Epoch 1, iteration 1018900: loss=1.4087, dev loss=1.5377
# 20:12:59 Epoch 1, iteration 1019000: loss=1.3975, dev loss=1.5350
# 20:13:03 Epoch 1, iteration 1019100: loss=1.3869, dev loss=1.5353
# 20:13:06 Epoch 1, iteration 1019200: loss=1.4019, dev loss=1.5370
# 20:13:10 Epoch 1, iteration 1019300: loss=1.3849, dev loss=1.5392
# 20:13:13 Epoch 1, iteration 1019400: loss=1.3974, dev loss=1.5388
# 20:13:17 Epoch 1, iteration 1019500: loss=1.3985, dev loss=1.5373
# 20:13:20 Epoch 1, iteration 1019600: loss=1.4083, dev loss=1.5358
# 20:13:24 Epoch 1, iteration 1019700: loss=1.3965, dev loss=1.5386
# 20:13:27 Epoch 1, iteration 1019800: loss=1.4008, dev loss=1.5376
# 20:13:31 Epoch 1, iteration 1019900: loss=1.3959, dev loss=1.5369
# 20:13:34 Epoch 1, iteration 1020000: loss=1.3924, dev loss=1.5364
# Checkpoint saved to last_checkpoint.pt
# ------------------------------
# Once upon a time, there was a little girl named Lily. She loved to play outside in the park. One day, she saw a boy with a shiny red ball. The boy looked very happy and said, "Wow, that's a cool ball! Can I play too?" Lily said, "Sure, you can play with my ball. But be careful not to drop it when you're done playing." One day, Lily said, "Can I borrow a ball too?" The boy said, "Sure
# ------------------------------
# 20:13:38 Epoch 1, iteration 1020100: loss=1.3885, dev loss=1.5387
# 20:13:42 Epoch 1, iteration 1020200: loss=1.3890, dev loss=1.5343
# 20:13:45 Epoch 1, iteration 1020300: loss=1.3919, dev loss=1.5381
# 20:13:49 Epoch 1, iteration 1020400: loss=1.3967, dev loss=1.5377
# 20:13:52 Epoch 1, iteration 1020500: loss=1.4042, dev loss=1.5367
# 20:13:56 Epoch 1, iteration 1020600: loss=1.4008, dev loss=1.5376
# 20:13:59 Epoch 1, iteration 1020700: loss=1.3991, dev loss=1.5387
# 20:14:03 Epoch 1, iteration 1020800: loss=1.4014, dev loss=1.5381
# 20:14:06 Epoch 1, iteration 1020900: loss=1.4070, dev loss=1.5393
# 20:14:10 Epoch 1, iteration 1021000: loss=1.3968, dev loss=1.5379
# 20:14:13 Epoch 1, iteration 1021100: loss=1.3889, dev loss=1.5385
# 20:14:17 Epoch 1, iteration 1021200: loss=1.4014, dev loss=1.5368
# 20:14:20 Epoch 1, iteration 1021300: loss=1.4022, dev loss=1.5363
# 20:14:23 Epoch 1, iteration 1021400: loss=1.3938, dev loss=1.5365
# 20:14:27 Epoch 1, iteration 1021500: loss=1.3976, dev loss=1.5363
# 20:14:30 Epoch 1, iteration 1021600: loss=1.4020, dev loss=1.5358
# 20:14:34 Epoch 1, iteration 1021700: loss=1.4020, dev loss=1.5372
# 20:14:37 Epoch 1, iteration 1021800: loss=1.3923, dev loss=1.5386
# 20:14:41 Epoch 1, iteration 1021900: loss=1.4045, dev loss=1.5376
# 20:14:44 Epoch 1, iteration 1022000: loss=1.3954, dev loss=1.5377
# 20:14:48 Epoch 1, iteration 1022100: loss=1.3985, dev loss=1.5386
# 20:14:51 Epoch 1, iteration 1022200: loss=1.3919, dev loss=1.5361
# 20:14:55 Epoch 1, iteration 1022300: loss=1.3969, dev loss=1.5357
# 20:14:58 Epoch 1, iteration 1022400: loss=1.3876, dev loss=1.5367
# 20:15:02 Epoch 1, iteration 1022500: loss=1.3937, dev loss=1.5371
# 20:15:05 Epoch 1, iteration 1022600: loss=1.4055, dev loss=1.5372
# 20:15:09 Epoch 1, iteration 1022700: loss=1.3828, dev loss=1.5377
# 20:15:12 Epoch 1, iteration 1022800: loss=1.4024, dev loss=1.5386
# 20:15:16 Epoch 1, iteration 1022900: loss=1.3885, dev loss=1.5370
# 20:15:19 Epoch 1, iteration 1023000: loss=1.3872, dev loss=1.5368
# 20:15:23 Epoch 1, iteration 1023100: loss=1.3966, dev loss=1.5382
# 20:15:26 Epoch 1, iteration 1023200: loss=1.3895, dev loss=1.5364
# 20:15:29 Epoch 1, iteration 1023300: loss=1.3965, dev loss=1.5386
# 20:15:33 Epoch 1, iteration 1023400: loss=1.3846, dev loss=1.5384
# 20:15:36 Epoch 1, iteration 1023500: loss=1.4008, dev loss=1.5366
# 20:15:40 Epoch 1, iteration 1023600: loss=1.4065, dev loss=1.5357
# 20:15:43 Epoch 1, iteration 1023700: loss=1.4056, dev loss=1.5390
# 20:15:47 Epoch 1, iteration 1023800: loss=1.3972, dev loss=1.5381
# 20:15:50 Epoch 1, iteration 1023900: loss=1.3985, dev loss=1.5361
# 20:15:54 Epoch 1, iteration 1024000: loss=1.4047, dev loss=1.5370
# 20:15:57 Epoch 1, iteration 1024100: loss=1.3941, dev loss=1.5374
# 20:16:01 Epoch 1, iteration 1024200: loss=1.4014, dev loss=1.5374
# 20:16:04 Epoch 1, iteration 1024300: loss=1.3853, dev loss=1.5395
# 20:16:08 Epoch 1, iteration 1024400: loss=1.3920, dev loss=1.5380
# 20:16:11 Epoch 1, iteration 1024500: loss=1.3880, dev loss=1.5394
# 20:16:15 Epoch 1, iteration 1024600: loss=1.4010, dev loss=1.5366
# 20:16:18 Epoch 1, iteration 1024700: loss=1.4009, dev loss=1.5372
# 20:16:22 Epoch 1, iteration 1024800: loss=1.4000, dev loss=1.5386
# 20:16:25 Epoch 1, iteration 1024900: loss=1.3909, dev loss=1.5395
# 20:16:29 Epoch 1, iteration 1025000: loss=1.4027, dev loss=1.5385
# 20:16:32 Epoch 1, iteration 1025100: loss=1.4004, dev loss=1.5400
# 20:16:36 Epoch 1, iteration 1025200: loss=1.3944, dev loss=1.5375
# 20:16:39 Epoch 1, iteration 1025300: loss=1.3926, dev loss=1.5375
# 20:16:43 Epoch 1, iteration 1025400: loss=1.4027, dev loss=1.5378
# 20:16:46 Epoch 1, iteration 1025500: loss=1.3917, dev loss=1.5383
# 20:16:50 Epoch 1, iteration 1025600: loss=1.3915, dev loss=1.5380
# 20:16:53 Epoch 1, iteration 1025700: loss=1.4093, dev loss=1.5362
# 20:16:57 Epoch 1, iteration 1025800: loss=1.4051, dev loss=1.5387
# 20:17:00 Epoch 1, iteration 1025900: loss=1.4001, dev loss=1.5358
# 20:17:04 Epoch 1, iteration 1026000: loss=1.4006, dev loss=1.5381

# %% [markdown]
# ### Use the model to generate stories
# Try varying the prompt, max tokens, temperature, and top-k sampling to study the effects.

# %%
def tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=0.8, top_k=40):
    device = next(model.parameters()).device
    
    # Encode prompt
    _, start_ids = tokenizer.tokenize(prompt)
    print(start_ids)
    x = torch.tensor(start_ids, dtype=torch.long, device=device)
    
    # Generate
    with torch.no_grad():
        y = model.generate(x, max_new_tokens=max_tokens, temperature=temperature, top_k=top_k)
    
    # Decode and print
    decoded_output = [tokenizer.vocab[i] for i in y.tolist()]
    print("-" * 30)
    print("".join(decoded_output))
    print("-" * 30)

checkpoint_path = "last_checkpoint.pt"
tokenizer_path = "/datasets/dd2417/tokenizer.json"
model = TinyStoriesLM.load(checkpoint_path, device='cuda')
tokenizer = TinyStoriesTokenizer.load(tokenizer_path)
# tell_story(model, tokenizer)

# %%
print("Conservative (low temp, low top-k)")
tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=0.5, top_k=20)
print("Balanced")
tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=0.8, top_k=40)
print("Creative (high temp, high top-k)")
tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=1.1, top_k=80)
# Out:
# Conservative (low temp, low top-k)
# [217, 223, 75, 192]
# ------------------------------
# Once upon a time, there was a little boy named Timmy. Timmy loved to play with his toy cars. One day, he was playing with his cars when his mom came in and said, "Timmy, we are going to the store to buy some candy." Timmy was so excited that he couldn't stop thinking about how to get all the candy. When they got to the store, Timmy's mom helped him get all the candy. Timmy was so happy that he started to jump up and down. He didn't want to
# ------------------------------
# Balanced
# [217, 223, 75, 192]
# ------------------------------
# Once upon a time, there was a little girl named Lily. She loved to play with her toys and eat cookies. One day, she found an enormous lemon tree in her backyard. She tried to pick the lemon, but it was too heavy for her. She asked her big brother to help her. "Can you help me pick the lemon, please?" she asked. Her brother said, "Yes, I can help you. But you must remain on me." So, Lily and her brother went to
# ------------------------------
# Creative (high temp, high top-k)
# [217, 223, 75, 192]
# ------------------------------
# Once upon a time, there was a little girl named Lily. One day, she went on a trip with her family to a cabin in the forest. The cabin was gloomy and Lily was sad because she lost her favorite toy. Mommy and daddy told Lily's daddy that he was sad because they had lost their favorite toy. They took Lily's daddy back to the cabin and he was very peaceful. Lily felt happy to be back with her family and they all hugged her. From that day on, Lily made sure to keep her
# ------------------------------

# %%
tell_story(model, tokenizer, prompt="Tom and Jerry went to", max_tokens=100, temperature=0.8, top_k=40)
# Out:
# [1584, 83, 2159, 239, 81]
# ------------------------------
# Tom and Jerry went to the park to play. They saw a big tree and wanted to climb it. Jerry was scared, but Jerry was brave. He said, "Let's climb the tree together!" So, Jerry and Tom climbed the tree. They were very brave. But then, something unexpected happened. Jerry got stuck! Tom was scared and said, "Help me, Jerry! You can't climb the tree!" Jerry knew he had to help. Jerry offered to climb the tree. Tom climbed the tree and found
# ------------------------------

# %%
tell_story(model, tokenizer, prompt="In a galaxy far far away", max_tokens=200, temperature=0.8, top_k=40)
# Out:
# [27, 35, 75, 112, 236, 302, 65, 821, 821, 391]
# ------------------------------
# In a galaxy far far away, and the cat wanted to find a new home. Tim wanted to help the cat find a new home. They walked and walked until they saw a big tree. The cat looked under the tree and found a beautiful new home. Tim and the cat were happy they found a new home. They became best friends and always helped each other when they were lost.Once upon a time, there was a little girl named Lily. She loved to play in the park with her friends. One day, Lily and her friends found a shiny gem on the ground. They were so happy and excited. Lily showed the gem to her friends and they all wanted to keep it forever. But then, Lily's friend Max started to cry because he wanted to keep it safe. Lily felt sad and didn't want to give it back. She asked Max if they could play with the gem but Max said no. Lily felt bad and decided to give the gem back to Max. Max was very happy and promised to take good care
# ------------------------------

# %%
print("Conservative (low temp, low top-k), 1 block, 1 head")
tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=0.5, top_k=20)
print("Balanced, 1 block, 1 head")
tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=0.8, top_k=40)
print("Creative (high temp, high top-k), 1 block, 1 head")
tell_story(model, tokenizer, prompt="Once upon a time", max_tokens=100, temperature=1.1, top_k=80)
print("Different prompt, higher max_tokens, 1 block, 1 head")
tell_story(model, tokenizer, prompt="Tom and Jerry went to", max_tokens=100, temperature=0.8, top_k=40)
tell_story(model, tokenizer, prompt="In a galaxy far far away", max_tokens=200, temperature=0.8, top_k=40)
# Out:
# Conservative (low temp, low top-k), 1 block, 1 head
# [217, 223, 75, 192]
# ------------------------------
# Once upon a time, there was a little girl named Lily. She loved to play with her dolls and teddy bears. One day, she went to the park to play with her friends. They played on the swings and the slide. They had so much fun together. After playing for a while, Lily and her friends decided to go home. They all said goodbye and went home. Lily was happy that she had a fun day at the park with her friends. She couldn't wait to come back again and play again.
# ------------------------------
# Balanced, 1 block, 1 head
# [217, 223, 75, 192]
# ------------------------------
# Once upon a time, there was a little bunny named Benny. Benny loved to play and hop around in the grass. One day, Benny decided to go on an adventure. He hopped around the forest until he saw a little bird sitting on a branch. "Hello little birdie," said Benny. "What are you doing in the forest?" "I'm trying to reach the top of the tree," replied the bird. "I want to help you," Benny said. "But please in the tree.
# ------------------------------
# Creative (high temp, high top-k), 1 block, 1 head
# [217, 223, 75, 192]
# ------------------------------
# Once upon a time, there was a little red car. This car was blue and shiny. It did not have a friend, a frog. The frog was patient as it jumped all day. One day, the little red car went for a ride. It saw a big tree in the middle of the street. The little red car was sure it needed the rest for its family. The little red car saw a big truck on the street. It wanted to know more about the world. So it did, so it
# ------------------------------
# Different prompt, higher max_tokens, 1 block, 1 head
# [1584, 83, 2159, 239, 81]
# ------------------------------
# Tom and Jerry went to the village. They were very happy because they were safe. One day, they found a big tree and decided to climb it. But when they tried to climb, they saw something unexpected. The tree was not like a tree, but a big bird. The bird had a nest on the tree. The bird looked at the tree and found three little eggs. The bird used its beak to fly away while the bird and Jerry came down from the tree. The bird and Jerry were very sad. The
# ------------------------------
# [27, 35, 75, 112, 236, 302, 65, 821, 821, 391]
# ------------------------------
# In a galaxy far far away." Lily was very excited to see what was inside, but her mom insisted that it was not safe for him to eat. Lily reluctantly ordered to try the grip of the grip and it tasted very yummy. She was so happy to have found her grip and eat the grip in her family. She had given it to her as a reward, and she was very pleased with herself and felt very proud of herself for being a good helper.Once upon a time, there was a little girl named Lily. She had a toy box that was locked. She wanted to open it, but she was too small to unlock it. Lily asked her mommy to help her unlock the box. Her mommy unlocked the box and Lily was very happy. She played with her toys and had a lot of fun. But then, Lily saw a toy she wanted to play with. She asked her mommy if she could play with it. Her mommy said no
# ------------------------------
